# %%
# !git clone https://github.com/ggerganov/llama.cpp.git

# %%
# !pip install -r llama.cpp/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly
# ...
#   Cloning https://github.com/huggingface/transformers (to revision v4.56.0-Embedding-Gemma-preview) to /tmp/pip-req-build-6falpz02
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-6falpz02
#   Running command git checkout -q 60b68e304cf4b6569b0660a13b558b929d4b0e77
#   Resolved https://github.com/huggingface/transformers to commit 60b68e304cf4b6569b0660a13b558b929d4b0e77
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Ignoring torch: markers 'platform_machine == "s390x"' don't match your environment
# ...

# %%
# !python llama.cpp/convert_hf_to_gguf.py ./gemma-3-1b-german-spelling   --outfile ./gemma-3-1b-german-spelling/gemma-3-1b-german-spelling.gguf --outtype q8_0
# Out:
# INFO:hf-to-gguf:Loading model: gemma-3-1b-german-spelling
# Traceback (most recent call last):
#   File "/home/ogu/workshop-ki-deepdive/llama.cpp/convert_hf_to_gguf.py", line 9167, in <module>
#     main()
#   File "/home/ogu/workshop-ki-deepdive/llama.cpp/convert_hf_to_gguf.py", line 9132, in main
#     model_architecture = get_model_architecture(hparams, model_type)
#   File "/home/ogu/workshop-ki-deepdive/llama.cpp/convert_hf_to_gguf.py", line 9062, in get_model_architecture
#     raise ValueError("Failed to detect model architecture")
# ValueError: Failed to detect model architecture

# %%
# !huggingface-cli

# %%
huggingface-cli upload oliverguhr/gemma-3-1b-german-spelling ./gemma-3-1b-german-spelling/gemma-3-1b-german-spelling.gguf gemma-3-1b-german-spelling.gguf
