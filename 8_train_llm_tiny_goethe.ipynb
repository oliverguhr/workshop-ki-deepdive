# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import lightning as L
from torch.utils.data import DataLoader, Dataset
from x_transformers import TransformerWrapper, Decoder
from x_transformers.autoregressive_wrapper import AutoregressiveWrapper
import numpy as np
import random
import argparse
import os
import shutil
from datasets import load_dataset, interleave_datasets
from transformers import DataCollatorForLanguageModeling,AutoTokenizer

from lightning.pytorch.callbacks import LearningRateMonitor, TQDMProgressBar
from lightning.pytorch.loggers import TensorBoardLogger

# %%
# !head -n 100 data/goethe.txt
# Out:
# I. Dramen
# II. Romane
# III. Erzählungen
# IV. Versepen
# V. Gedichte
# VI. Aufzeichnungen und Aphorismen
# VII. Ästhetik
# VIII. Naturwissenschaft
# IX. Autobiographisches
#
#
# ———
# d r a m e n
# ———
# *
# Die Laune des Verliebten
# (1767/68)
# Die Mitschuldigen
# (1768/69)
# Götz von Berlichingen
# mit der eisernen Hand
# (1773)
# Prometheus
# (1773)
# Satyros
# (1773)
# Götter, Helden und Wieland
# (1773)
# Ein Fastnachtsspiel vom Pater Brey
# (1773/74)
# Das Jahrmarktsfest zu Plundersweilern
# (1773–78)
# Erwin und Elmire
# (1774/75)
# Claudine von Villa Bella
# (1774/75)
# Faust [in ursprünglicher Gestalt]
# (1772–75)
# Clavigo
# (1774)
# Hanswursts Hochzeit
# (1775)
# Stella
# (1776)
# Die Geschwister
# (17)
# Proserpina
# (1778)
# Der Triumph der Empfindsamkeit
# (1778/79)
# Egmont
# (1775–87)
# Iphigenie auf Tauris
# (1779–86)
# Torquato Tasso
# (1780–88)
# Der Großkophta
# (1792)
# Der Bürgergeneral
# (1793)
# Die Aufgeregten
# (1793)
# Mahomet der Prophet
# (1802)
# Die natürliche Tochter
# (1799–1803)
# Faust: Der Tragödie erster Teil
# (1797–1806)
# Pandora
# (1810)
# Des Epimenides Erwachen
# (1815)
# Faust: Der Tragödie zweiter Teil
# (1825–31)
#
#
# Johann Wolfgang Goethe
#
#
# Die Laune
# des
# Verliebten
#
# Ein Schäferspiel in Versen und einem Akte
# Entstanden 1767/68.
# Erstdruck in: Werke, Tübingen (Cotta) 1806.
# Uraufführung am 20.5.1779 in Weimar.
#
# ———
# l a u n e
# ———
# *
# Personen
# Erster Auftritt
# Zweiter Auftritt
# Dritter Auftritt
# Vierter Auftritt
# Fünfter Auftritt
# Sechster Auftritt

# %%
# !mkdir -p models/goethe

# %%
training_files = ["data/goethe.txt"]

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.decoders import BPEDecoder
from transformers import PreTrainedTokenizerFast

# 1. Define your special tokens
special_tokens = ["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"]

# 2. Create the tokenizer
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
trainer = BpeTrainer(special_tokens=special_tokens, min_frequency=2, end_of_word_suffix='</w>', vocab_size=1000)

tokenizer.pre_tokenizer = Whitespace()
tokenizer.decoder = BPEDecoder(suffix='</w>')
tokenizer.enable_padding(pad_token="[PAD]", pad_id=special_tokens.index("[PAD]"))

print("Training tokenizer...")
tokenizer.train(training_files, trainer)

# 3. Create PreTrainedTokenizerFast with explicit token mappings
goethe_tokenizer = PreTrainedTokenizerFast(
    tokenizer_object=tokenizer,
    unk_token="[UNK]",
    cls_token="[CLS]", 
    sep_token="[SEP]",
    pad_token="[PAD]",
    mask_token="[MASK]"
)

# 4. Verify the special tokens are set properly
goethe_tokenizer.model_max_length = 100
goethe_tokenizer.save_pretrained("models/goethe/goethenizer")

print("Number of tokens:", goethe_tokenizer.vocab_size)
print("PAD token id:", goethe_tokenizer.pad_token_id)
print("All special tokens:", goethe_tokenizer.all_special_tokens)
print("All special IDs:", goethe_tokenizer.all_special_ids)

# 5. Test if the tokenizer works correctly
test_text = "Dies ist ein Test."
encoded = goethe_tokenizer.encode(test_text, padding="max_length", max_length=20)
print("Encoded with padding:", encoded)
print("Decoded back:", goethe_tokenizer.decode(encoded, skip_special_tokens=True))
# Out:
# Training tokenizer...
#
#
#
# Number of tokens: 1000
# PAD token id: 3
# All special tokens: ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']
# All special IDs: [0, 2, 3, 1, 4]
# Encoded with padding: [34, 309, 176, 371, 331, 50, 63, 323, 213, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Decoded back: Dies ist ein Test .

# %%
encoded = goethe_tokenizer.encode("Dies ist fuer sie.")
print("Encoded tokens:", encoded)
decoded = goethe_tokenizer.decode(encoded)
print("Decoded text:", decoded)
# Out:
# Encoded tokens: [34, 309, 176, 371, 64, 79, 297, 357, 213]
# Decoded text: Dies ist fuer sie .

# %% [markdown]
# # Define a Model
#
# Documentation for X-Transformers [here](https://github.com/lucidrains/x-transformers).

# %%
class SequenceDecoder(L.LightningModule):
    def __init__(self, sequence_length, learn_rate, tokenizer):
        super().__init__()
        # instantiate GPT-like decoder model
        transformer_model = TransformerWrapper(
            num_tokens = tokenizer.vocab_size+1,
            max_seq_len = sequence_length,
            emb_dropout=0.1,
            use_abs_pos_emb=False, # replace absolute pos embeddings with relative ones (rotary_xpos)
            l2norm_embed = True,
            attn_layers = Decoder(
                dim = 256,
                depth = 4,
                heads = 4,
                attn_flash = True, # flash attention
                rotary_xpos = True, # improved version of rotary_pos_emb
                ff_swish = True, #SwiGLU from PaLM and LLaMA
                attn_one_kv_head = True, # improves speed, does not cost much performance
                attn_head_scale = True,
                ff_no_bias = True, # faster and better \o/
                #layer_dropout = 0.1,   # stochastic depth - dropout entire layer
                attn_dropout = 0.1,    # dropout post-attention
                ff_dropout = 0.1       # feedforward dropout
            )
        )

        self.model = AutoregressiveWrapper(transformer_model,mask_prob=0.0, pad_value=tokenizer.pad_token_id) # test again with 0.15
        self.learn_rate = learn_rate
        self.tokenizer = tokenizer
        self.save_hyperparameters(ignore=["tokenizer"])

    def forward(self,x):
        return self.model.forward(x["input_ids"])

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.learn_rate,)
        return optimizer

    def training_step(self, train_batch, batch_idx):
        loss = self.model(train_batch["input_ids"])
        self.log('train_perplexity', torch.exp(loss), on_step=True, on_epoch=True, prog_bar=True)
        self.log('train_loss', loss, on_step=True, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(self, val_batch, batch_idx):
        self.model.eval()
        with torch.no_grad():
            loss = self.model(val_batch["input_ids"])

        self.log('val_perplexity', torch.exp(loss), on_epoch=True, prog_bar=True)
        self.log('val_loss', loss, on_epoch=True, prog_bar=True)

    def on_validation_epoch_end(self):
        #model.eval()
        #item = next(iter(val_loader.dataset))
        #mask = item['attention_mask'].clone().detach().to(torch.bool)
        #ids = item['input_ids'].clone().detach()[mask].to(self.device)

        #prompt = self.tokenizer.decode(ids,skip_special_tokens=False)
        prompt = "Der Mensch ist ein"
        ids = torch.tensor(self.tokenizer.encode(prompt)).to(self.device)
        sample = self.model.generate(ids, 20, temperature=0.7, filter_kwargs={"k": 10})
        output_str = self.tokenizer.decode(sample.cpu().numpy(),skip_special_tokens=False)
        output_str = output_str.replace(self.tokenizer.sep_token, "\n")
        print(f'prompt: {prompt}\ngeneration:{output_str}')

# %% [markdown]
# # Prepare the data

# %%
SEQ_LEN = 100
BATCH_SIZE = 256
MODEL_PATH = "./models/goethe"

# Load tokenizer
#tokenizer = AutoTokenizer.from_pretrained("LeoLM/leo-hessianai-7b-chat", trust_remote_code=True) # <-- much better
tokenizer = AutoTokenizer.from_pretrained("models/goethe/goethenizer")
tokenizer.model_max_length = SEQ_LEN

# Load raw text data
raw_dataset = load_dataset("text", data_files={"train": training_files}, split="train")

# Tokenize the entire text at once
def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=False, padding=False)

# Tokenize all texts and concatenate them
tokenized_dataset = raw_dataset.map(
    tokenize_function, 
    batched=True, 
    remove_columns=["text"]
)

# Concatenate all tokenized texts into a single list of tokens
all_token_ids = []
for example in tokenized_dataset:
    all_token_ids.extend(example["input_ids"])
    all_token_ids.append(tokenizer.sep_token_id)  # Preserve the original line break

# Create a custom dataset class for continuous token sequences
class ContinuousTokenDataset(Dataset):
    def __init__(self, token_ids, seq_length):
        self.token_ids = token_ids
        self.seq_length = seq_length
        self.total_sequences = len(token_ids) - seq_length + 1
    
    def __len__(self):
        return self.total_sequences
    
    def __getitem__(self, idx):
        # Get a sequence of tokens starting at position idx
        input_ids = self.token_ids[idx:idx + self.seq_length]
        # Create labels identical to input_ids for autoregressive language modeling
        return {
            "input_ids": torch.tensor(input_ids),
            "labels": torch.tensor(input_ids)
        }

# Create train/validation split - splitting the token indices, not the dataset itself
total_sequences = len(all_token_ids) - SEQ_LEN + 1
train_size = int(0.99 * total_sequences)
val_size = total_sequences - train_size

# Create datasets
train_dataset = ContinuousTokenDataset(all_token_ids[:train_size + SEQ_LEN - 1], SEQ_LEN)
val_dataset = ContinuousTokenDataset(all_token_ids[train_size:], SEQ_LEN)

# Create dataloaders
# Note: We don't need DataCollatorForLanguageModeling since our dataset already provides labels
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Map:   0%|          | 0/143777 [00:00<?, ? examples/s]
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (122 > 100). Running this sequence through the model will result in indexing errors

# %%
print(val_dataset[0])
# Out:
# {'input_ids': tensor([ 48, 346, 446, 567, 498, 345, 213,   2,  49, 369,  72, 773, 181,  31,
#         477, 182,  66, 751, 171, 302, 903, 315, 487, 343, 417, 525, 211, 335,
#         906, 416, 339, 349, 210, 562,  43, 369, 773,  65, 176, 789, 302, 827,
#         580,  74, 411, 430, 785, 213,  36, 398, 367, 491, 410, 319, 605,  60,
#         368, 606, 630,  80, 529,  84, 330, 173, 602, 401, 421, 322, 731, 211,
#         359, 421, 730, 339, 480, 643, 800, 318, 352, 173,  78,  66,  79, 173,
#         213, 470, 831, 946, 367, 349, 669,  43,  73, 379,  80, 171,  63,  65,
#          59, 187]), 'labels': tensor([ 48, 346, 446, 567, 498, 345, 213,   2,  49, 369,  72, 773, 181,  31,
#         477, 182,  66, 751, 171, 302, 903, 315, 487, 343, 417, 525, 211, 335,
#         906, 416, 339, 349, 210, 562,  43, 369, 773,  65, 176, 789, 302, 827,
#         580,  74, 411, 430, 785, 213,  36, 398, 367, 491, 410, 319, 605,  60,
#         368, 606, 630,  80, 529,  84, 330, 173, 602, 401, 421, 322, 731, 211,
#         359, 421, 730, 339, 480, 643, 800, 318, 352, 173,  78,  66,  79, 173,
#         213, 470, 831, 946, 367, 349, 669,  43,  73, 379,  80, 171,  63,  65,
#          59, 187])}

# %%
tokenizer.decode(val_dataset[1]['input_ids'],skip_special_tokens=True)
# Out:
# 'ollen geschrieben . Sonntag Abend hoffe ich Ihnen es vorzulesen , versagen Sie sich nicht ; denn Montags muß ich Leseprobe halten . Freilich wenn man die Arbeit könnte vierzehn Tage liegen lassen , so ließe sich noch manches daran thun . Ich konnte freilich nicht alle Motive egal aus'

# %%
print("Pretrained PAD token id:", tokenizer.pad_token_id)
print( tokenizer.all_special_ids)
print( tokenizer.all_special_tokens)
# Out:
# Pretrained PAD token id: 3
# [0, 2, 3, 1, 4]
# ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']

# %%
print("Pretrained PAD token id:", tokenizer.pad_token_id)
print( tokenizer.all_special_ids)
print( tokenizer.all_special_tokens)
# Out:
# Pretrained PAD token id: 3
# [0, 2, 3, 1, 4]
# ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']

# %% [markdown]
# # Train the Model

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6008 (pid 713492), started 0:28:55 ago. (Use '!kill 713492' to kill it.)
#       <iframe id="tensorboard-frame-54ac43cdfde3b921" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-54ac43cdfde3b921");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
torch.set_float32_matmul_precision("high")

model = SequenceDecoder(sequence_length=SEQ_LEN,learn_rate=0.0002, tokenizer=tokenizer)

lr_monitor = LearningRateMonitor(logging_interval='step')
progress_bar = TQDMProgressBar(refresh_rate=10)
logger = TensorBoardLogger("lightning_logs", name=type(model).__name__ )

trainer = L.Trainer(accelerator="gpu",
                    devices=1,
                    precision="bf16-mixed",
                    max_epochs=2,
                    log_every_n_steps=5,
                    val_check_interval = 500,
                    accumulate_grad_batches=2,
                    gradient_clip_val=0.7,
                    limit_train_batches=1.0,
                    limit_val_batches=0.2,
                    logger=logger,
                    enable_progress_bar=True,
                    callbacks=[lr_monitor, progress_bar])

trainer.fit(model, train_loader, val_loader)

checkpoint = MODEL_PATH +"/sequence_decoder_model.ckpt"
print(f"saving finished model to {checkpoint}")
trainer.save_checkpoint(checkpoint)

trainer.validate(model=model, dataloaders=val_loader, ckpt_path=None)
# Out:
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type                  ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ AutoregressiveWrapper │  3.3 M │ train │     0 │
# └───┴───────┴───────────────────────┴────────┴───────┴───────┘
# Trainable params: 3.3 M
# Non-trainable params: 0
# Total params: 3.3 M
# Total estimated model params size (MB): 13.069
# Modules in train mode: 136
# Modules in eval mode: 0
# Total FLOPs: 0
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:kt o ünst† underC or immwurwürVoro or wurdann welche welche immo Ζ
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schauer ,
# Dein Herz und Manut .
# Denn es ist
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Körper , den er sich in den Partenten zu versetzen ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Buch , der sie sich so bedeuten ,
# Und sie erblickt und die
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Pfeil und Sitten ! –
# Darf ich , sie liebt ihn
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Scheid , er kann sich nicht bestehen ,
# Denn es ist
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes , das Schauspiel der Gott , die sich besser zu ver
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:unbequemes , aber es ist auch das Licht von dem Ganzen .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Feuer als der Heiligkeit , der die Natur in der Natur , und was sie
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Mann , der sich in seinem Betragen verweilte . Die Fe
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes Glück .
# Aber wenn ich die Freiheit gesagt hatte
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Tor , und ich habe die Hand gesagt .
# gonzalo .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Prisma , welches der Mensch nur im Auge ist , die sich nicht
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , das , wenn er ’ s weiß , und ich habe ihn zu tun .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schatten , das , was er hat , ist er nicht gewesen , sondern er
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Höllenschein , der sich zu einem gewissen Bedürfnis zu machen
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schöner Glück , und man kann sich nicht enthalten .
# Die Gräf
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:bißchen und sich zu schätzen .
# Die Probe wird von dem P
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch .
#
# ––––––
# » Was willst du nicht mit uns be
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Mensch , aber das andre soll ihm nicht enthalten .
# Wenn wir nun
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der sich mit ihm entschließen läßt , der sich zu verglei
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , und die Selbstgefälligkeit ist , wird die Künste
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schatz , den man nennt , und der Poet wird sich entschlie
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Pfand , der sie ist ,
# Und wenn er nur ein Schatz und Scha
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der in den Händen des Lebens steht , wenn der D
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Traum , der sich nur um sich hat , und es ist ein großer Vortei
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Publikum , das nicht das Gute , das sie nicht zu überdenken pf
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , und es ist ein Schatz .
# Der König ist sehr schön
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , der hat , wie er es ergreift .
#
# *
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Traum , ein Himmel , der mit ihm sich zu treiben pflegt
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schauspiel ,
# Er wird sich mit den Händen entfliehn .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schlechter ,
# So weit , so gut als ein Ganzes ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schöner Teil , er ist auch der Schritt .
# marqui
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , und ich will ihn nicht . Sobald ich mich betrüge ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schauspiel .
# götz .
# Was hast du ’ s ?
# rö
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Führer , der nicht in der Welt ist , der sich von der S
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Meister ; der König ist kein Gott , das ist eine Art von
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:ungeheurer Teil der Dichtkunst , und es ist nichts ü
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fehler , der sie in der Welt verfuhr , den wir in die Welt hin
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gefühl , und was soll es ihm sein , wenn er sich nicht verleugnet
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer , und der Mensch verlangt nicht . – Es ist ein Teuf
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Mann , und man wird es ihm nicht abgewinnen .
#
# *
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der sich so bald in der Welt ergänzt . Er ist ein K
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes , und er ist ein schlechter , wohlgekleidete
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil der Erde ,
# Und ein Meer , der den andern breit
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:König und die Welt ;
# Die Tiefe schwebt ein Mädchen ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Theater , der die Gräber von sich selbst erscheinen läßt .
# al
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Mensch ; man ist es nicht so , wie er sich selbst gemacht hat .«
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Traum von seinen Stirn . – Er ist nicht der Geist in seinem
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schatten , wenn er ihn nur zu seinem Behagen erzeugt .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes , und die Fürstin selbst ist eine unüberwindliche Ge
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:bißchen schlecht .
# Der Schmerz des Dichters ist
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:gutes , unbewußtes Wesen , ein Geistreiches und Bel
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Tod , daß er den Schritt tut , und das ist eben die Welt ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schönes Gefühl ,
# Und das Leben ist ein Schicksal ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Hauptmann , der das Schicksal , das Gute , das
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schuster , das sich selbst macht , und man wird sich ’ s nicht enthalten .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Held , das ihm so schmeichelt ,
# Das Unrecht , das ist
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer , ein Bürger , der nicht ein Schauspiel ist , und das
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott .
# Der Dichter macht die Götter , und der Mut
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil der Pflicht , der in seinem Leben gemalt ist , wenn er
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Handwerk , die Tugend , die Beschwerde , den sie verb
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:bißchen leidlich , aber er ist nicht zu verwundern . Und so ist
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Traum , das uns bestimmt , das uns bedroht , und so
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil des Künstlers , das , was er will , und das ist ihm
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Traum ,
# Und das ist das Glück , das sich in ihm verlor
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil der Mutter ,
# Das ist ein Schicksal !
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schauspieler , und die Frauen werden ihn nicht entschuldigen , er
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Meister , und der Teufel wird nicht so viel gesagt , daß er
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Mann ,
# Den sie ihm nicht vertraut .
#
# –––––
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Knabe , der den Tod des Menschen verbirgt . Du hast
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Mensch .
#
# *
#
#
# Der Geister
#
# Sol
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch ; der Mensch muß seine Gesinnungen verstehen , wenn er sich be
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil der Natur , und man kann nicht sagen , daß sie ihm nicht versagt ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes Unternehmen .
# Man kann sich nicht genug ergeben , daß die
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schatz , der nicht verkennt ist , und der Mensch wird sich nicht verglei
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:braves , schönes Glück .
# Die Himmlischen , die
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schöpfer .
#
# [ Entstanden 1782 , Erstdruck 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes , und es ist ihm nicht die Natur , der sich nicht in der Figu
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der ist ’ s , der die Heilige zu sehn ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , der sich selbst versteht , und so ist er auch ein Fortsch
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Kenner , der nicht einmal in der Ferne steht , und der Gott
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mann , der nicht weiß , was er ist , und was er will , und wenn er auch nicht
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Glück , der sich nicht mit dem andern vereinigt , der nur durch das Ver
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer , und der Hauptfraß wird auch auf jede Weise ver
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:braver Mann , der sich nicht mit seinem Gemüt verbindet .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Mensch von dem andern , der sich zu einem jeden bestätigt
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fest .
#
# ––––
# Der Mensch ist gar zu gern ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der das Glück der Natur hat !
# Er ist nicht zu viel ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schönes Wort ,
# Und es hat der Glück , der sich ergrei
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil der Natur , der nicht verleugnen kann ; er wird es nicht aus
# `Trainer.fit` stopped: `max_epochs=2` reached.
# `weights_only` was not set, defaulting to `False`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# saving finished model to ./models/goethe/sequence_decoder_model.ckpt
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil der Welt , der es besieht , und die Forschung , die
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │     2.635805368423462     │
# │      val_perplexity       │     14.46108627319336     │
# └───────────────────────────┴───────────────────────────┘
# [{'val_perplexity': 14.46108627319336, 'val_loss': 2.635805368423462}]

# %% [markdown]
# # Generate some Texts

# %%
from x_transformers.autoregressive_wrapper import top_p, top_k

model.eval()

def ask_model(prompt, max_new_tokens=10, temperature=0.7):
  start = torch.tensor(tokenizer.encode(prompt)).to("cpu")
  sample = model.model.generate(start, max_new_tokens, temperature=temperature, filter_logits_fn=top_k, filter_kwargs={"k": 10})
  sample = sample.to("cpu")
  output_str = tokenizer.decode(sample.numpy(),skip_special_tokens=False)
  output_str = output_str.replace(tokenizer.sep_token, "\n")
  print(prompt + " " + output_str)

# %%
ask_model("Ach meine Liebe ,", max_new_tokens=100, temperature=0.4)
# Out:
# Ach meine Liebe ,
# Die du mir verzeihst ,
# Mein Herz ist ein Traum .
#
# Du hast sie , so ist es
# Im Busen ,
# Du verbannst mich .
#
# Du hast mich ergetzt
# Und treibst mir die Schöne
# Und die du ,
# Und du ,
# Du bist mein .
#
# Du bist mein , ich hab es
# Und werde mich
