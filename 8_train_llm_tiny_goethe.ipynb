# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import lightning as L
from torch.utils.data import DataLoader, Dataset
from x_transformers import TransformerWrapper, Decoder
from x_transformers.autoregressive_wrapper import AutoregressiveWrapper
import numpy as np
import random
import argparse
import os
import shutil
from datasets import load_dataset, interleave_datasets
from transformers import DataCollatorForLanguageModeling,AutoTokenizer

from lightning.pytorch.callbacks import LearningRateMonitor, TQDMProgressBar
from lightning.pytorch.loggers import TensorBoardLogger
# Out:
# /home/ogu/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/torch/jit/_script.py:1485: FutureWarning: `torch.jit.script` is not supported in Python 3.14+ and may break. Please switch to `torch.compile` or `torch.export`.
#   warnings.warn(

# %%
# !head -n 100 data/goethe.txt
# Out:
# I. Dramen
# II. Romane
# III. Erzählungen
# IV. Versepen
# V. Gedichte
# VI. Aufzeichnungen und Aphorismen
# VII. Ästhetik
# VIII. Naturwissenschaft
# IX. Autobiographisches
#
#
# ———
# d r a m e n
# ———
# *
# Die Laune des Verliebten
# (1767/68)
# Die Mitschuldigen
# (1768/69)
# Götz von Berlichingen
# mit der eisernen Hand
# (1773)
# Prometheus
# (1773)
# Satyros
# (1773)
# Götter, Helden und Wieland
# (1773)
# Ein Fastnachtsspiel vom Pater Brey
# (1773/74)
# Das Jahrmarktsfest zu Plundersweilern
# (1773–78)
# Erwin und Elmire
# (1774/75)
# Claudine von Villa Bella
# (1774/75)
# Faust [in ursprünglicher Gestalt]
# (1772–75)
# Clavigo
# (1774)
# Hanswursts Hochzeit
# (1775)
# Stella
# (1776)
# Die Geschwister
# (17)
# Proserpina
# (1778)
# Der Triumph der Empfindsamkeit
# (1778/79)
# Egmont
# (1775–87)
# Iphigenie auf Tauris
# (1779–86)
# Torquato Tasso
# (1780–88)
# Der Großkophta
# (1792)
# Der Bürgergeneral
# (1793)
# Die Aufgeregten
# (1793)
# Mahomet der Prophet
# (1802)
# Die natürliche Tochter
# (1799–1803)
# Faust: Der Tragödie erster Teil
# (1797–1806)
# Pandora
# (1810)
# Des Epimenides Erwachen
# (1815)
# Faust: Der Tragödie zweiter Teil
# (1825–31)
#
#
# Johann Wolfgang Goethe
#
#
# Die Laune
# des
# Verliebten
#
# Ein Schäferspiel in Versen und einem Akte
# Entstanden 1767/68.
# Erstdruck in: Werke, Tübingen (Cotta) 1806.
# Uraufführung am 20.5.1779 in Weimar.
#
# ———
# l a u n e
# ———
# *
# Personen
# Erster Auftritt
# Zweiter Auftritt
# Dritter Auftritt
# Vierter Auftritt
# Fünfter Auftritt
# Sechster Auftritt

# %%
# !mkdir -p models/goethe

# %%
training_files = ["data/goethe.txt"]

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.decoders import BPEDecoder
from transformers import PreTrainedTokenizerFast

# 1. Define your special tokens
special_tokens = ["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"]

# 2. Create the tokenizer
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
trainer = BpeTrainer(special_tokens=special_tokens, min_frequency=2, end_of_word_suffix='</w>', vocab_size=1000)

tokenizer.pre_tokenizer = Whitespace()
tokenizer.decoder = BPEDecoder(suffix='</w>')
tokenizer.enable_padding(pad_token="[PAD]", pad_id=special_tokens.index("[PAD]"))

print("Training tokenizer...")
tokenizer.train(training_files, trainer)

# 3. Create PreTrainedTokenizerFast with explicit token mappings
goethe_tokenizer = PreTrainedTokenizerFast(
    tokenizer_object=tokenizer,
    unk_token="[UNK]",
    cls_token="[CLS]", 
    sep_token="[SEP]",
    pad_token="[PAD]",
    mask_token="[MASK]"
)

# 4. Verify the special tokens are set properly
goethe_tokenizer.model_max_length = 100
goethe_tokenizer.save_pretrained("models/goethe/goethenizer")

print("Number of tokens:", goethe_tokenizer.vocab_size)
print("PAD token id:", goethe_tokenizer.pad_token_id)
print("All special tokens:", goethe_tokenizer.all_special_tokens)
print("All special IDs:", goethe_tokenizer.all_special_ids)

# 5. Test if the tokenizer works correctly
test_text = "Dies ist ein Test."
encoded = goethe_tokenizer.encode(test_text, padding="max_length", max_length=20)
print("Encoded with padding:", encoded)
print("Decoded back:", goethe_tokenizer.decode(encoded, skip_special_tokens=True))
# Out:
# Training tokenizer...
#
#
#
# Number of tokens: 1000
# PAD token id: 3
# All special tokens: ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']
# All special IDs: [0, 2, 3, 1, 4]
# Encoded with padding: [34, 309, 173, 371, 331, 50, 63, 323, 198, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Decoded back: Dies ist ein Test .

# %%
encoded = goethe_tokenizer.encode("Dies ist fuer sie.")
print("Encoded tokens:", encoded)
decoded = goethe_tokenizer.decode(encoded)
print("Decoded text:", decoded)
# Out:
# Encoded tokens: [34, 309, 173, 371, 64, 79, 297, 357, 198]
# Decoded text: Dies ist fuer sie .

# %% [markdown]
# # Define a Model
#
# Documentation for X-Transformers [here](https://github.com/lucidrains/x-transformers).

# %%
class SequenceDecoder(L.LightningModule):
    def __init__(self, sequence_length, learn_rate, tokenizer):
        super().__init__()
        # instantiate GPT-like decoder model
        transformer_model = TransformerWrapper(
            num_tokens = tokenizer.vocab_size+1,
            max_seq_len = sequence_length,
            emb_dropout=0.1,
            use_abs_pos_emb=False, # replace absolute pos embeddings with relative ones (rotary_xpos)
            l2norm_embed = True,
            attn_layers = Decoder(
                dim = 256,
                depth = 4,
                heads = 4,
                attn_flash = True, # flash attention
                rotary_xpos = True, # improved version of rotary_pos_emb
                ff_swish = True, #SwiGLU from PaLM and LLaMA
                attn_one_kv_head = True, # improves speed, does not cost much performance
                attn_head_scale = True,
                ff_no_bias = True, # faster and better \o/
                #layer_dropout = 0.1,   # stochastic depth - dropout entire layer
                attn_dropout = 0.1,    # dropout post-attention
                ff_dropout = 0.1       # feedforward dropout
            )
        )

        self.model = AutoregressiveWrapper(transformer_model,mask_prob=0.0, pad_value=tokenizer.pad_token_id) # test again with 0.15
        self.learn_rate = learn_rate
        self.tokenizer = tokenizer
        self.save_hyperparameters()

    def forward(self,x):
        return self.model.forward(x["input_ids"])

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.learn_rate,)
        return optimizer

    def training_step(self, train_batch, batch_idx):
        loss = self.model(train_batch["input_ids"])
        self.log('train_perplexity', torch.exp(loss), on_step=True, on_epoch=True, prog_bar=True)
        self.log('train_loss', loss, on_step=True, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(self, val_batch, batch_idx):
        self.model.eval()
        with torch.no_grad():
            loss = self.model(val_batch["input_ids"])

        self.log('val_perplexity', torch.exp(loss), on_epoch=True, prog_bar=True)
        self.log('val_loss', loss, on_epoch=True, prog_bar=True)

    def on_validation_epoch_end(self):
        #model.eval()
        #item = next(iter(val_loader.dataset))
        #mask = item['attention_mask'].clone().detach().to(torch.bool)
        #ids = item['input_ids'].clone().detach()[mask].to(self.device)

        #prompt = self.tokenizer.decode(ids,skip_special_tokens=False)
        prompt = "Der Mensch ist ein"
        ids = torch.tensor(self.tokenizer.encode(prompt)).to(self.device)
        sample = self.model.generate(ids, 20, temperature=0.7, filter_kwargs={"k": 10})
        output_str = self.tokenizer.decode(sample.cpu().numpy(),skip_special_tokens=False)
        print(f'prompt: {prompt}\ngeneration:{output_str}')

# %% [markdown]
# # Prepare the data

# %%
SEQ_LEN = 100
BATCH_SIZE = 256
MODEL_PATH = "./models/goethe"

# Load tokenizer
#tokenizer = AutoTokenizer.from_pretrained("LeoLM/leo-hessianai-7b-chat", trust_remote_code=True) # <-- much better
tokenizer = AutoTokenizer.from_pretrained("models/goethe/goethenizer")
tokenizer.model_max_length = SEQ_LEN

# Load raw text data
raw_dataset = load_dataset("text", data_files={"train": training_files}, split="train")

# Tokenize the entire text at once
def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=False, padding=False)

# Tokenize all texts and concatenate them
tokenized_dataset = raw_dataset.map(
    tokenize_function, 
    batched=True, 
    remove_columns=["text"]
)

# Concatenate all tokenized texts into a single list of tokens
all_token_ids = []
for example in tokenized_dataset:
    all_token_ids.extend(example["input_ids"])

# Create a custom dataset class for continuous token sequences
class ContinuousTokenDataset(Dataset):
    def __init__(self, token_ids, seq_length):
        self.token_ids = token_ids
        self.seq_length = seq_length
        self.total_sequences = len(token_ids) - seq_length + 1
    
    def __len__(self):
        return self.total_sequences
    
    def __getitem__(self, idx):
        # Get a sequence of tokens starting at position idx
        input_ids = self.token_ids[idx:idx + self.seq_length]
        # Create labels identical to input_ids for autoregressive language modeling
        return {
            "input_ids": torch.tensor(input_ids),
            "labels": torch.tensor(input_ids)
        }

# Create train/validation split - splitting the token indices, not the dataset itself
total_sequences = len(all_token_ids) - SEQ_LEN + 1
train_size = int(0.99 * total_sequences)
val_size = total_sequences - train_size

# Create datasets
train_dataset = ContinuousTokenDataset(all_token_ids[:train_size + SEQ_LEN - 1], SEQ_LEN)
val_dataset = ContinuousTokenDataset(all_token_ids[train_size:], SEQ_LEN)

# Create dataloaders
# Note: We don't need DataCollatorForLanguageModeling since our dataset already provides labels
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Map:   0%|          | 0/143777 [00:00<?, ? examples/s]
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (122 > 100). Running this sequence through the model will result in indexing errors

# %%
print(val_dataset[0])
# Out:
# {'input_ids': tensor([171, 698, 317, 217, 302, 596, 427, 299,  74, 104, 100, 367, 306, 882,
#         315, 480, 217, 670, 867, 312, 324,  64, 303, 317, 339, 429, 349, 553,
#         198, 442, 183, 365, 324, 444, 635, 397, 293, 306,  50, 498, 187, 434,
#         354, 302,  68, 757, 728,  73, 412, 326, 916,  50, 575, 658, 511, 476,
#         316, 347, 171, 198, 470, 417, 401, 350,  32, 400, 838, 364,  56, 320,
#         393, 173, 748, 374, 927, 481, 217, 350, 339, 481, 405, 480, 695, 799,
#         578, 198, 791, 416, 741, 553, 306,  69, 610, 293, 416, 366, 808, 385,
#          36, 414]), 'labels': tensor([171, 698, 317, 217, 302, 596, 427, 299,  74, 104, 100, 367, 306, 882,
#         315, 480, 217, 670, 867, 312, 324,  64, 303, 317, 339, 429, 349, 553,
#         198, 442, 183, 365, 324, 444, 635, 397, 293, 306,  50, 498, 187, 434,
#         354, 302,  68, 757, 728,  73, 412, 326, 916,  50, 575, 658, 511, 476,
#         316, 347, 171, 198, 470, 417, 401, 350,  32, 400, 838, 364,  56, 320,
#         393, 173, 748, 374, 927, 481, 217, 350, 339, 481, 405, 480, 695, 799,
#         578, 198, 791, 416, 741, 553, 306,  69, 610, 293, 416, 366, 808, 385,
#          36, 414])}

# %%
tokenizer.decode(val_dataset[1]['input_ids'],skip_special_tokens=True)
# Out:
# 'worden , ich selbst war unpäßlich und bin es noch , meine Kinder befanden sich auch nicht wohl . Bei dem besten Willen und Trieb werde ich jetzt gar oft in meiner Thätigkeit gehindert . Ich lege das Blatt von Zelters Aufsatz bei , das sich bei mir noch gefunden hat . Leben Sie recht wohl und kehren Sie mit schönen Früchten'

# %%
print("Pretrained PAD token id:", tokenizer.pad_token_id)
print( tokenizer.all_special_ids)
print( tokenizer.all_special_tokens)
# Out:
# Pretrained PAD token id: 3
# [0, 2, 3, 1, 4]
# ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']

# %%
print("Pretrained PAD token id:", tokenizer.pad_token_id)
print( tokenizer.all_special_ids)
print( tokenizer.all_special_tokens)
# Out:
# Pretrained PAD token id: 3
# [0, 2, 3, 1, 4]
# ['[UNK]', '[SEP]', '[PAD]', '[CLS]', '[MASK]']

# %% [markdown]
# # Train the Model

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs
# Out:
#       <iframe id="tensorboard-frame-b22bd33cbbb48e3c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b22bd33cbbb48e3c");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
torch.set_float32_matmul_precision("high")

model = SequenceDecoder(sequence_length=SEQ_LEN,learn_rate=0.0002, tokenizer=tokenizer)

lr_monitor = LearningRateMonitor(logging_interval='step')
progress_bar = TQDMProgressBar(refresh_rate=10)
logger = TensorBoardLogger("lightning_logs", name=type(model).__name__ )

trainer = L.Trainer(accelerator="gpu",
                    devices=1,
                    precision="bf16-mixed",
                    max_epochs=2,
                    log_every_n_steps=5,
                    val_check_interval = 500,
                    accumulate_grad_batches=2,
                    gradient_clip_val=0.7,
                    limit_train_batches=1.0,
                    limit_val_batches=0.2,
                    logger=logger,
                    enable_progress_bar=True,
                    callbacks=[lr_monitor, progress_bar])

trainer.fit(model, train_loader, val_loader)
trainer.validate(dataloaders=val_loader)
#
#
checkpoint = MODEL_PATH +"/sequence_decoder_model.ckpt"
print (f"saveing finished model to " +checkpoint)
trainer.save_checkpoint(checkpoint)
# Out:
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /home/ogu/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type                  ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ AutoregressiveWrapper │  3.3 M │ train │     0 │
# └───┴───────┴───────────────────────┴────────┴───────┴───────┘
# Trainable params: 3.3 M
# Non-trainable params: 0
# Total params: 3.3 M
# Total estimated model params size (MB): 13.069
# Modules in train mode: 136
# Modules in eval mode: 0
# Total FLOPs: 0
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/ogu/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /home/ogu/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=47` in the `DataLoader` to improve performance.
# prompt: Der Mensch ist ein
# generation:Mke j beneistspieΑimmer vieMbensehr j MéeigenΑMhäVer
# /home/ogu/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=47` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:, der die Tur , die in der Talente , die sie , und die
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Glück , Und wenn man sich die Gesichtskrispf verb
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schicksal , der er sich nicht fehlt , so wird sie nicht verlan
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Grab , und der Kompliment , der sich so unerwartet
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schiff , das er in der Welt , Der sich so schnell erz
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Feuer , der König und Hoffnungsart . * Sie
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schuldner , Der Gott ist so viel als die Stimmung . D
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Tropfen , und so wird es nicht verkümmert , wenn man sie nicht
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes Papier , Das ist ein edler Gut , der ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Geist . görge . Du bist nicht der , so ist die Gö
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gut , der du , der dich schlachtet , Wo ist er ? Er
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Geheimnis . –––––– » Das wird nicht leicht ein Glück sein
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Blut , er wird ’ s nicht . –––––– » Ich weiß wohl nicht ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott ! Er wird nicht gesund , und es gibt sich , und ich füh
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Wunder und der Feldglanz , Der ist der Fahrzeu
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Geheimnis , der sich der Held behandelt , Und er ver
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , wenn ’ s ein Gott verdankt ; Doch ich hab
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fürst in dein Herz . Und der Himmel , dem du dich so t
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , der sich von ihm abschlagt . Er ist , wie er sich bet
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schwaches Gesicht , Und der Held ist behaglich , Die Gö
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Brunnen . faust . Du bist ein ewiger Geist
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Triumph . Du kannst nicht , du hast dich nicht
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Blatt , das ihm verdient . Das Feuer , das die Natur ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Geist , und der wird sich nicht bequem befreit .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der sich von dem Schatten verläßt . Die Freiheit und
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Künstler , und er ist auch nur ein Schriftsteller , daß er in
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Feuer , der ein Phänomen , der sich nicht befriedigen
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gleichnis , der sich in dem Augenblicke erheben kann . Denn
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Wunder . –––––– » Wer hat das Recht ?« Ich glaube
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Werk , der ihn umgeben , und er wird nicht verdrießen , er kann
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , und er sieht die Natur , wie er es braucht . ––––
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fest , die er gemacht hat , Die sich in dem Augenblick verb
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fehler , der sich nicht zu berühren hat . Und was man vernünf
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Knabe . Er hat das Schicksal von den Künsten und Ku
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gleichniß , und wir sind nicht gesagt , und die Stimme
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Blick , das er verbunden hat , Der Genuß hat , der sich
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fall , der sich ergeben muß , und so ist es nicht anders . Er sieht
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:ungesäumter , der ein Frauenzimmer verkündigt
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schauspieler , der sich zu verstehn scheint . Die Musik ist
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gefühl des Menschen , und man muß nur deswegen das Glück errei
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gesicht und nicht zu schwer , Und doch kann er nicht sein , er muß nach
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Künstler von dem , was man ihm versagt . Die Physiogn
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott ! – Du bist ein Mann , der dich in die Höhe sch
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes Behagen , Und was er nicht kennt , ist nicht die höch
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Paar , das er vernommen , Dann ist er nicht zu vernich
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Tun und Talent , Der Menschheit , des Geistes , des
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fürst , der , der uns begegnet , Den Blick zu ver
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Trost , wie ich ihn gesehen habe . Es ist mir ein ewiger Besch
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schauspieler und der Philosophie . Und so ist es , wie
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der ein Prädikat betrübt , Und der K
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , der sich nicht in seinem Leben befindet , Und er ist nur mit seinem G
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , der sich von seiner Natur bewegt , Er hat ’ s nicht so gena
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Künstler , und der Mensch kann sich nicht besser finden ; man kann es nicht ver
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , das er zu verlangen versteht , Und er ist nicht zu sch
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der sich in der Gegenwart so verbindet . Wer die
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fall , ein Trunkenes . Wie du dich in diesen Tagen befieh
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Glück , der sie sich vernimmt , und wenn er auch nicht in der N
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schüler , und der Mensch kann nur das , was er hat . Und nun ! –
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mann , der sich in seinem Leben bewußt , Sein Auge zu sein , seine
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schatten , der das Gefühl seiner Gestalt in seinem Schatten verl
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , der nicht zu bekennen weiß , und der Mensch kann nichts weiter da
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schüler , der sich in seinem Herzen befindet , und seine Grunds
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großes Geheimnis , und es ist der Künstler , der nicht immer
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer Schein , Und er hat es recht . –––––– » Der Bu
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Geheimnis zu verlieren . Denn wenn er sich in seiner Art be
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mensch , der sich nicht verkennt . –––––– Ich habe sie verlor
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Heer ! Du sollst dich betören , Du siehst
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schuldischer , der sich nicht mit sich selbst verbindet ; Denn das
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mann , der nicht zu verstehen weiß . Die Philosophie hat sich
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schauer , und die Mühe muß nicht vergessen , und die Meinungen
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:ungeheueres Unternehmen ! Du hast es nicht gesehen , du
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Künstler , den er gefühlt hat . Und doch ist es , was wir verstän
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schöner , der ein Geist hat , und es ist ein Glücklicher ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Feld . Welch ein Fell ! welch ein Wind ! W
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer , der das Bedürfnis seiner Gemahlin , und es
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:unwiderstehlicher Unterschied , wenn er sich nicht mit seiner Gatt
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Fest , das er nicht besitzt . Der Dichter steigt her
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott ! – Was soll das heißen ? – Und das versteht sich nicht .
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:schöner Mann , Der in seinem Leben verlor . Und wenn du nicht bist ,
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mann , der in seiner Gegenwart sich zu verlieren hat ; er betrü
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Mann von großem Vermögen , Und ich muß ihm die Hand bezahlen
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schatz , das er in seinen Traum hinauszuschließen . Sieh
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Teil der Grazie der Dinge . Es ist nicht ein Künstler
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:unerträglicher Geist . Und so schnell , wenn es sch
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , daß er sich nicht besser befreit hat . Er ist ein gro
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:großer König , Der hat sich in jedem Kreise gesetzt Und
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Gott , der sich in seinem Innern zu erzeugen weiß . Die P
# Validation: |          | 0/? [00:00<?, ?it/s]
# prompt: Der Mensch ist ein
# generation:Schritt , der die Gabe zu schätzen weiß . Das Schicksa
# `Trainer.fit` stopped: `max_epochs=2` reached.
# /home/ogu/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py:149: `.validate(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.validate(ckpt_path='best')` to use the best model or `.validate(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at lightning_logs/SequenceDecoder/version_0/checkpoints/epoch=1-step=22115.ckpt
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[14], line 24
#      20                     enable_progress_bar=True,
#      21                     callbacks=[lr_monitor, progress_bar])
#      22
#      23 trainer.fit(model, train_loader, val_loader)
# ---> 24 trainer.validate(dataloaders=val_loader)
#      25 #
#      26 #
#      27 checkpoint = MODEL_PATH +"/sequence_decoder_model.ckpt"
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/trainer.py:702, in Trainer.validate(self, model, dataloaders, ckpt_path, verbose, datamodule, weights_only)
#     700 self.state.status = TrainerStatus.RUNNING
#     701 self.validating = True
# --> 702 return call._call_and_handle_interrupt(
#     703     self, self._validate_impl, model, dataloaders, ckpt_path, verbose, datamodule, weights_only
#     704 )
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/trainer.py:745, in Trainer._validate_impl(self, model, dataloaders, ckpt_path, verbose, datamodule, weights_only)
#     741     download_model_from_registry(ckpt_path, self)
#     742 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     743     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     744 )
# --> 745 results = self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     746 # remove the tensors from the validation results
#     747 results = convert_tensors_to_scalars(results)
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/trainer.py:1046, in Trainer._run(self, model, ckpt_path, weights_only)
#    1044 if not self.strategy.restore_checkpoint_after_setup:
#    1045     log.debug(f"{self.__class__.__name__}: restoring module and callbacks from checkpoint path: {ckpt_path}")
# -> 1046     self._checkpoint_connector._restore_modules_and_callbacks(ckpt_path, weights_only)
#    1048 # reset logger connector
#    1049 self._logger_connector.reset_results()
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py:410, in _CheckpointConnector._restore_modules_and_callbacks(self, checkpoint_path, weights_only)
#     406 def _restore_modules_and_callbacks(
#     407     self, checkpoint_path: Optional[_PATH] = None, weights_only: Optional[bool] = None
#     408 ) -> None:
#     409     # restore modules after setup
# --> 410     self.resume_start(checkpoint_path, weights_only=weights_only)
#     411     self.restore_model()
#     412     self.restore_datamodule()
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py:83, in _CheckpointConnector.resume_start(self, checkpoint_path, weights_only)
#      81 rank_zero_info(f"Restoring states from the checkpoint path at {checkpoint_path}")
#      82 with pl_legacy_patch():
# ---> 83     loaded_checkpoint = self.trainer.strategy.load_checkpoint(checkpoint_path, weights_only=weights_only)
#      84 self._loaded_checkpoint = _pl_migrate_checkpoint(loaded_checkpoint, checkpoint_path)
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/pytorch/strategies/strategy.py:368, in Strategy.load_checkpoint(self, checkpoint_path, weights_only)
#     366 def load_checkpoint(self, checkpoint_path: _PATH, weights_only: Optional[bool] = None) -> dict[str, Any]:
#     367     torch.cuda.empty_cache()
# --> 368     return self.checkpoint_io.load_checkpoint(checkpoint_path, weights_only=weights_only)
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/fabric/plugins/io/torch_io.py:91, in TorchCheckpointIO.load_checkpoint(self, path, map_location, weights_only)
#      88 if not fs.exists(path):
#      89     raise FileNotFoundError(f"Checkpoint file not found: {path}")
# ---> 91 return pl_load(path, map_location=map_location, weights_only=weights_only)
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/lightning/fabric/utilities/cloud_io.py:73, in _load(path_or_url, map_location, weights_only)
#      71 fs = get_filesystem(path_or_url)
#      72 with fs.open(path_or_url, "rb") as f:
# ---> 73     return torch.load(
#      74         f,
#      75         map_location=map_location,  # type: ignore[arg-type]
#      76         weights_only=weights_only,
#      77     )
#
# File ~/source/workshop-ki-deepdive/.venv/lib/python3.14/site-packages/torch/serialization.py:1614, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1605                 return _load(
#    1606                     opened_zipfile,
#    1607                     map_location,
#    (...)   1611                     **pickle_load_args,
#    1612                 )
#    1613             except pickle.UnpicklingError as e:
# -> 1614                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1615         return _load(
#    1616             opened_zipfile,
#    1617             map_location,
#    (...)   1621             **pickle_load_args,
#    1622         )
#    1623 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL transformers.tokenization_utils_tokenizers.TokenizersBackend was not an allowed global by default. Please use `torch.serialization.add_safe_globals([transformers.tokenization_utils_tokenizers.TokenizersBackend])` or the `torch.serialization.safe_globals([transformers.tokenization_utils_tokenizers.TokenizersBackend])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %% [markdown]
# # Generate some Texts

# %%
from x_transformers.autoregressive_wrapper import top_p, top_k

model.eval()

def ask_model(prompt, max_new_tokens=10, temperature=0.7):
  start = torch.tensor(tokenizer.encode(prompt)).to("cpu")
  sample = model.model.generate(start, max_new_tokens,temperature=temperature,filter_logits_fn=top_k)
  sample = sample.to("cpu")
  output_str = tokenizer.decode(sample.numpy(),skip_special_tokens=False)
  print(prompt + " " + output_str)

# %%
ask_model("Was begehrt das Herz mehr als eine", max_new_tokens=100, temperature=0.7)
# Out:
# Was begehrt das Herz mehr als eine vernünftige Freude ? Was lernt ihr mit so viel Kühnheit zu sagen ? Ihr habt euch genug gesehn , ihr Herren , daß ihr den Busen so lang als möglich zu sehen versprecht , als wenn ihr es künftig begegnet . Ach , wenn ich nicht die Silben , die euch zum erstenmal erbarmen , ich hätte sie überrei
